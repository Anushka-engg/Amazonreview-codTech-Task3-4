# %%
from google.colab import files

uploaded = files.upload()  # This will open a file upload dialog
# Out:
#      <input type="file" id="files-50cbf70e-987d-4a19-acfd-f02e5be4f2ec" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-50cbf70e-987d-4a19-acfd-f02e5be4f2ec">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os

print(os.listdir())  # This should list 'cleaned_data.csv'
# Out:
# ['.config', 'cleaned_data.csv', 'sample_data']

# %%
import pandas as pd

df = pd.read_csv("cleaned_data.csv")
print(df.head())  # Show first 5 rows
# Out:
#                                                 Text  Score Sentiment
# 0  I have bought several of the Vitality canned d...    5.0  Positive
# 1  "Product arrived labeled as Jumbo Salted Peanu...    1.0  Negative
# 2  "This is a confection that has been around a f...    4.0  Positive
# 3  If you are looking for the secret ingredient i...    2.0  Negative
# 4  Great taffy at a great price.  There was a wid...    5.0  Positive

# %%
# Out:
# Streaming output truncated to the last 5000 lines.
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# ...

# %%
df.to_csv("final_sentiment_data.csv", index=False)

# %%
import joblib

# Save the model
joblib.dump(sia, "sentiment_model.pkl")

# Load it later when needed
loaded_model = joblib.load("sentiment_model.pkl")

# %%
plt.savefig("sentiment_distribution.png", dpi=300, bbox_inches="tight")

# %%
df.to_csv("final_sentiment_data.csv", index=False)
print("CSV file saved successfully!")
# Out:
# CSV file saved successfully!

# %%
# Save sentiment distribution plot
plt.figure(figsize=(6, 4))
sns.countplot(x=df["sentiment"], palette="viridis")
plt.title("Sentiment Distribution")
plt.savefig("sentiment_distribution.png", dpi=300, bbox_inches="tight")
plt.show()

# Save word clouds
wordcloud_pos = WordCloud(background_color="white").generate(" ".join(df[df["sentiment"] == "Positive"]["cleaned_text"].dropna()))
wordcloud_neg = WordCloud(background_color="black").generate(" ".join(df[df["sentiment"] == "Negative"]["cleaned_text"].dropna()))

wordcloud_pos.to_file("wordcloud_positive.png")
wordcloud_neg.to_file("wordcloud_negative.png")
print("Word cloud images saved successfully!")
# Out:
# <ipython-input-15-2d772313d2fc>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df["sentiment"], palette="viridis")
# Word cloud images saved successfully!

# %%
import joblib

joblib.dump(sia, "sentiment_model.pkl")
print("Model saved successfully!")
# Out:
# Model saved successfully!
